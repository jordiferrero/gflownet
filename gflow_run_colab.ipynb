# %% [markdown]
# ## Either git clone mount GDrive

# %% [markdown]
# Git clone

# %%
#!git clone https://github.com/recursionpharma/gflownet

# %%
#cd gflownet

# %% [markdown]
# Mount GDrive

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
cd ../gdrive/MyDrive/Code/gflownet
# Out:
# /gdrive/MyDrive/Code/gflownet

# %% [markdown]
# ## Install dependencies according to requirements

# %%
# !pwd
# Out:
# /gdrive/MyDrive/Code/gflownet

# %%
# Should show if using GPU or not
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %% [markdown]
# Will need to restart session and rerun from this cell onwards.

# %%
# GPU
# !pip install -e . --find-links https://data.pyg.org/whl/torch-2.1.2+cu121.html
# CPU only
# !pip install -e . --find-links https://data.pyg.org/whl/torch-2.1.2+cpu.html

# %% [markdown]
# ## Run code

# %%
# !python src/gflownet/tasks/seh_frag_moo.py
# Out:
# Traceback (most recent call last):
#   File "/gdrive/MyDrive/Code/gflownet/src/gflownet/tasks/seh_frag_moo.py", line 7, in <module>
#     import torch_geometric.data as gd
# ModuleNotFoundError: No module named 'torch_geometric'
